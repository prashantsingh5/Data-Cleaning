# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading the Dataset

# %%
data = pd.read_csv("nyc-property-sales.csv",low_memory=False)

# %% [markdown]
# # Exploring the Data

# %%
data.head()
# Out:
#   BOROUGH   NEIGHBORHOOD         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0       1  ALPHABET CITY         01 ONE FAMILY DWELLINGS                    1
# 1       1  ALPHABET CITY         02 TWO FAMILY DWELLINGS                    1
# 2       1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                   2B
# 3       1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                   2B
# 4       1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS                    2
#
#   BLOCK LOT EASE-MENT BUILDING CLASS AT PRESENT                    ADDRESS  \
# 0   374  46       NaN                        A4        347 EAST 4TH STREET
# 1   377   1       NaN                        S2               110 AVENUE C
# 2   373  16       NaN                        C1        326 EAST 4TH STREET
# 3   373  17       NaN                        C1        328 EAST 4TH STREET
# 4   376  54       NaN                        C4  719 EAST SIXTH STREET, 1B
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2018049 entries, 0 to 2018048
# Data columns (total 21 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   BOROUGH                         object
#  1   NEIGHBORHOOD                    object
#  2   BUILDING CLASS CATEGORY         object
#  3   TAX CLASS AT PRESENT            object
#  4   BLOCK                           object
#  5   LOT                             object
#  6   EASE-MENT                       object
#  7   BUILDING CLASS AT PRESENT       object
#  8   ADDRESS                         object
#  9   APARTMENT NUMBER                object
#  10   ZIP CODE                       object
#  11  RESIDENTIAL UNITS               object
#  12  COMMERCIAL UNITS                object
#  13  TOTAL UNITS                     object
#  14  LAND SQUARE FEET                object
#  15  GROSS SQUARE FEET               object
#  16  YEAR BUILT                      object
# ...

# %%
data.shape
# Out:
# (2018049, 21)

# %%
data.columns
# Out:
# Index(['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', ' ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')

# %%
data["BOROUGH"].unique()
# Out:
# array(['1', '2', '3', '4', '5', 'BOROUGH'], dtype=object)

# %%
data[data["BOROUGH"] == "BOROUGH"]
# Out:
#          BOROUGH  NEIGHBORHOOD  BUILDING CLASS CATEGORY  TAX CLASS AT PRESENT  \
# 1879248  BOROUGH  NEIGHBORHOOD  BUILDING CLASS CATEGORY  TAX CLASS AT PRESENT
#
#          BLOCK  LOT EASE-MENT  BUILDING CLASS AT PRESENT  ADDRESS  \
# 1879248  BLOCK  LOT  EASEMENT  BUILDING CLASS AT PRESENT  ADDRESS
#
#          APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 1879248  APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS
#
#          TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 1879248  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT
#
#          TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 1879248  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE
#
#          SALE PRICE  SALE DATE
# 1879248  SALE PRICE  SALE DATE
#
# [1 rows x 21 columns]

# %%
data = data.drop(1879248)  # removing the data that contain 'BOROUGH' in BOROUGH column

# %%
data["NEIGHBORHOOD"] = data["NEIGHBORHOOD"].str.strip()   # removing the empty spaces from name

# %%
data["NEIGHBORHOOD"].unique()  # checking if this column contains null value or any other unnecessary values
# Out:
# array(['ALPHABET CITY', 'CHELSEA', 'CHINATOWN', 'CIVIC CENTER', 'CLINTON',
#        'EAST VILLAGE', 'FASHION', 'FINANCIAL', 'FLATIRON', 'GRAMERCY',
#        'GREENWICH VILLAGE-CENTRAL', 'GREENWICH VILLAGE-WEST',
#        'HARLEM-CENTRAL', 'HARLEM-EAST', 'HARLEM-UPPER', 'HARLEM-WEST',
#        'INWOOD', 'JAVITS CENTER', 'KIPS BAY', 'LITTLE ITALY',
#        'LOWER EAST SIDE', 'MANHATTAN VALLEY', 'MIDTOWN CBD',
#        'MIDTOWN EAST', 'MIDTOWN WEST', 'MORNINGSIDE HEIGHTS',
#        'MURRAY HILL', 'ROOSEVELT ISLAND', 'SOHO', 'SOUTHBRIDGE',
#        'TRIBECA', 'UPPER EAST SIDE (59-79)', 'UPPER EAST SIDE (79-96)',
#        'UPPER EAST SIDE (96-110)', 'UPPER WEST SIDE (59-79)',
#        'UPPER WEST SIDE (79-96)', 'UPPER WEST SIDE (96-116)',
#        'WASHINGTON HEIGHTS LOWER', 'WASHINGTON HEIGHTS UPPER', 'BATHGATE',
#        'BAYCHESTER', 'BEDFORD PARK/NORWOOD', 'BELMONT', 'BRONX PARK',
#        'BRONXDALE', 'CASTLE HILL/UNIONPORT', 'CITY ISLAND',
# ...

# %%
data["BUILDING CLASS CATEGORY"].unique()
# Out:
# array(['01 ONE FAMILY DWELLINGS', '02 TWO FAMILY DWELLINGS',
#        '07 RENTALS - WALKUP APARTMENTS',
#        '08 RENTALS - ELEVATOR APARTMENTS', '09 COOPS - WALKUP APARTMENTS',
#        '10 COOPS - ELEVATOR APARTMENTS', '12 CONDOS - WALKUP APARTMENTS',
#        '13 CONDOS - ELEVATOR APARTMENTS', '14 RENTALS - 4-10 UNIT',
#        '15 CONDOS - 2-10 UNIT RESIDENTIAL', '17 CONDO COOPS',
#        '28 COMMERCIAL CONDOS', '29 COMMERCIAL GARAGES', '30 WAREHOUSES',
#        '46 CONDO STORE BUILDINGS', '03 THREE FAMILY DWELLINGS',
#        '04 TAX CLASS 1 CONDOS',
#        '16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT',
#        '21 OFFICE BUILDINGS', '22 STORE BUILDINGS', '25 LUXURY HOTELS',
#        '26 OTHER HOTELS', '43 CONDO OFFICE BUILDINGS', '44 CONDO PARKING',
#        '47 CONDO NON-BUSINESS STORAGE',
#        '48 CONDO TERRACES/GARDENS/CABANAS', '31 COMMERCIAL VACANT LAND',
#        '37 RELIGIOUS FACILITIES', '11 SPECIAL CONDO BILLING LOTS',
# ...

# %%
data_to_remove = data[data["BUILDING CLASS CATEGORY"] == "                                            "]   # BUILDING CLASS CATEGORY is empty

# %%
index_list = data_to_remove.index.tolist()

# %%
mask = ~data.index.isin(index_list)
data = data[mask]

# %%
data["TAX CLASS AT PRESENT"].unique()
# Out:
# array(['1', '2B', '2', '2A', '2C', '4', '1C', nan, '1A', '1B', '1D', ' ',
#        '  ', '3'], dtype=object)

# %%
data_remove1 = data[data["TAX CLASS AT PRESENT"] == ' ']
index_list1 = data_remove1.index.tolist()
data_remove2 = data[data["TAX CLASS AT PRESENT"] == '  ']
index_list2 = data_remove2.index.tolist()
index_list3 = index_list1 + index_list2

# %%
len(index_list3)
# Out:
# 18981

# %%
mask = ~data.index.isin(index_list3)
data = data[mask]

# %%
data["EASE-MENT"].unique()   #EASE-MENT column contains more than 30 to 40 nan values hence I am removing this column
# Out:
# array([nan, ' ', 'E'], dtype=object)

# %%
data = data.drop('EASE-MENT', axis = 1)

# %%
data["BUILDING CLASS AT PRESENT"].unique()
# Out:
# array(['A4', 'S2', 'C1', 'C4', 'C2', 'C7', 'D6', 'D3', 'C6', 'D4', 'D0',
#        'R2', 'R4', 'S9', 'S4', 'S3', 'R1', 'R9', 'R5', 'G7', 'E7', 'V1',
#        'RK', 'A9', 'S1', 'B9', 'C0', 'R6', 'C5', 'D7', 'D9', 'S5', 'R8',
#        'O3', 'O6', 'O5', 'K4', 'K2', 'K9', 'H2', 'H3', 'E1', 'RB', 'RG',
#        'RP', 'RS', 'RT', 'O2', 'RA', 'M9', 'C3', nan, 'O9', 'G9', 'G1',
#        'P9', 'D1', 'D5', 'O4', 'K7', 'Z9', 'RH', 'D8', 'H8', 'G6', 'B1',
#        'D2', 'K1', 'P2', 'A5', 'B2', 'B3', 'C9', 'RR', 'HH', 'I5', 'W4',
#        'M1', 'M2', 'Y4', 'O8', 'K3', 'H9', 'G2', 'HR', 'N2', 'A1', 'G3',
#        'GW', 'E9', 'Q1', 'A7', 'R3', 'H1', 'HS', 'HB', 'W3', 'Z5', 'J4',
#        'P5', 'RW', 'C8', 'O7', 'H7', 'Z4', 'S0', 'F1', 'M3', 'J6', 'H6',
#        'G4', 'V0', 'I9', 'N9', 'A2', 'Z0', 'H4', 'F4', 'G8', 'G0', 'A6',
#        'V8', 'Q8', 'V2', 'A3', 'F5', 'I7', 'G5', 'Q9', 'P6', 'V9', 'F9',
#        'E2', 'M4', 'O1', 'A8', 'V3', 'K5', 'P8', 'I1', 'W2', 'W9', 'V5',
# ...

# %%
data["ADDRESS"].unique()    # Address column doesn't need any deletion and updation
# Out:
# array(['347 EAST 4TH STREET', '110 AVENUE C', '326 EAST 4TH STREET', ...,
#        '45 HELENE COURT', '72 HELENE COURT', '35 RED CEDAR LANE'],
#       dtype=object)

# %%
data["APARTMENT NUMBER"].unique()    #nan values can be tackeled in later stage
# Out:
# array([nan, 'B1', 'D1', ..., 'S-2L', 'CP23', 'L-H'], dtype=object)

# %%
data["YEAR BUILT"].unique()    #only nan value needs updation hence it can be targeted later
# Out:
# array(['1900.0', '1901.0', '1899.0', '1920.0', '1910.0', '1930.0',
#        '1940.0', '1915.0', '1925.0', '1928.0', '1923.0', '1950.0',
#        '1935.0', '1937.0', '1929.0', nan, '2014.0', '2013.0', '2009.0',
#        '1960.0', '2003.0', '2017.0', '2006.0', '1989.0', '1850.0',
#        '1938.0', '1944.0', '2020.0', '1999.0', '2019.0', '1974.0',
#        '1987.0', '1905.0', '1864.0', '1921.0', '1917.0', '1911.0',
#        '1983.0', '1902.0', '1963.0', '1926.0', '1913.0', '1889.0',
#        '1898.0', '1939.0', '1918.0', '1927.0', '1906.0', '1909.0',
#        '1958.0', '2015.0', '2007.0', '2018.0', '2005.0', '2008.0',
#        '2016.0', '1931.0', '1985.0', '1984.0', '2002.0', '2004.0',
#        '1875.0', '2012.0', '1973.0', '2011.0', '1922.0', '1851.0',
#        '2001.0', '1932.0', '1980.0', '1908.0', '1924.0', '1912.0',
#        '1880.0', '1990.0', '2021.0', '1991.0', '1988.0', '1965.0',
#        '1890.0', '2010.0', '1860.0', '1957.0', '1986.0', '1961.0',
# ...

# %%
data["BUILDING CLASS AT TIME OF SALE"].unique()
# Out:
# array(['A4', 'S2', 'C1', 'C4', 'C2', 'C7', 'D6', 'D3', 'C6', 'D4', 'D0',
#        'R2', 'R4', 'S9', 'S4', 'S3', 'R1', 'R9', 'R5', 'G7', 'E7', 'RK',
#        'A9', 'S1', 'B9', 'C0', 'R6', 'C5', 'D7', 'D9', 'S5', 'R8', 'O3',
#        'O6', 'O5', 'K4', 'K2', 'K9', 'H2', 'H3', 'E1', 'RB', 'RG', 'RP',
#        'RS', 'RT', 'O2', 'V1', 'M9', 'RR', 'C3', 'O9', 'G9', 'G1', 'P9',
#        'D1', 'RA', 'D5', 'O4', 'K7', 'Z9', 'RH', 'D8', 'H8', 'G6', 'B1',
#        'D2', 'K1', 'P2', 'A5', 'B2', 'B3', 'C9', 'HH', 'I5', 'W4', 'M1',
#        'M2', 'Y4', 'O8', 'K3', 'H9', 'G2', 'HR', 'N2', 'A1', 'G3', 'GW',
#        'E9', 'R3', 'H1', 'HS', 'HB', 'A7', 'W3', 'Z5', 'J4', 'P5', 'RW',
#        'C8', 'O7', 'H7', 'Z4', 'S0', 'F1', 'M3', 'J6', 'H6', 'G4', 'V0',
#        'I9', 'N9', 'A2', 'Z0', 'H4', 'F4', 'G8', 'G0', 'A6', 'V8', 'Q8',
#        'V2', 'A3', 'F5', 'V9', 'I7', 'G5', 'W9', 'Q9', 'P6', 'F9', 'E2',
#        'M4', 'O1', 'A8', 'V3', 'K5', 'P8', 'I1', 'W2', 'V5', 'P7', 'K6',
# ...

# %% [markdown]
# # Changing the Datatypes of columns

# %%
data["BLOCK"] = data["BLOCK"].astype(float)
data["LOT"] = data["LOT"].astype(float)
data[" ZIP CODE"] = data[" ZIP CODE"].astype(float)
data["RESIDENTIAL UNITS"] = data["RESIDENTIAL UNITS"].astype(float)
data["COMMERCIAL UNITS"] = data["COMMERCIAL UNITS"].astype(float)
data["TOTAL UNITS"] = data["TOTAL UNITS"].astype(float)
data["LAND SQUARE FEET"] = data["LAND SQUARE FEET"].astype(float)
data["GROSS SQUARE FEET"] = data["GROSS SQUARE FEET"].astype(float)
data["TAX CLASS AT TIME OF SALE"] = data["TAX CLASS AT TIME OF SALE"].astype(float)
data["SALE PRICE"] = data["SALE PRICE"].astype(float)    # In case of model training this column acts as target variable
data['SALE DATE'] = data['SALE DATE'].str.split(' ').str[0]   # removing time from this column because time is always zero

# %% [markdown]
# # Checking whether the nan values is present or not

# %%
data.columns
# Out:
# Index(['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'BUILDING CLASS AT PRESENT',
#        'ADDRESS', 'APARTMENT NUMBER', ' ZIP CODE', 'RESIDENTIAL UNITS',
#        'COMMERCIAL UNITS', 'TOTAL UNITS', 'LAND SQUARE FEET',
#        'GROSS SQUARE FEET', 'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
#        'BUILDING CLASS AT TIME OF SALE', 'SALE PRICE', 'SALE DATE'],
#       dtype='object')

# %%
print("Number of nan values present in NEIGHBORHOOD",len(data[data["NEIGHBORHOOD"].isnull()]))                                       # this doesn't contain any nan values
print("Number of nan values present in BUILDING CLASS CATEGORY",len(data[data["BUILDING CLASS CATEGORY"].isnull()]))                 # this doesn't contain any nan values
print("Number of nan values present in BUILDING CLASS AT PRESENT",len(data[data["BUILDING CLASS AT PRESENT"].isnull()]))             # This column contains 838 nan rows
print("Number of nan values present in BUILDING CLASS AT PRESENT",len(data[data["BUILDING CLASS AT PRESENT"].isnull()]))             # This column contains 838 nan rows
print("Number of nan values present in TAX CLASS AT PRESENT",len(data[data["TAX CLASS AT PRESENT"].isnull()]))                       # This column contains 838 nan rows
print("Number of nan values present in BLOCK",len(data[data["BLOCK"].isnull()]))                                                     # this doesn't contain any nan values
print("Number of nan values present in LOT",len(data[data["LOT"].isnull()]))                                                         # this doesn't contain any nan values
print("Number of nan values present in ADDRESS",len(data[data["ADDRESS"].isnull()]))                                                 # this doesn't contain any nan values
print("Number of nan values present in APARTMENT NUMBER",len(data[data["APARTMENT NUMBER"].isnull()]))                               # this column contains 470673 nan rows. So we can either remove those rows or delete the column
print("Number of nan values present in ZIP CODE",len(data[data[" ZIP CODE"].isnull()]))                                              # this column contais 47 nan rows
print("Number of nan values present in RESIDENTIAL UNITS",len(data[data["RESIDENTIAL UNITS"].isnull()]))                             # this column contains 120893 rows
print("Number of nan values present in COMMERCIAL UNITS",len(data[data["COMMERCIAL UNITS"].isnull()]))                               # this column contains 190743 rows
print("Number of nan values present in TOTAL UNITS",len(data[data["TOTAL UNITS"].isnull()]))                                         # this column contains 109684 rows
print("Number of nan values present in LAND SQUARE FEET",len(data[data["LAND SQUARE FEET"].isnull()]))                               # this column contains 201953 rows
print("Number of nan values present in GROSS SQUARE FEET",len(data[data["GROSS SQUARE FEET"].isnull()]))                             # this column contains 201952 rows
print("Number of nan values present in YEAR BUILT",len(data[data["YEAR BUILT"].isnull()]))                                           # this column contains 36651 rows
print("Number of nan values present in TAX CLASS AT TIME OF SALE",len(data[data["TAX CLASS AT TIME OF SALE"].isnull()]))             # this doesn't contain any nan values
print("Number of nan values present in BUILDING CLASS AT TIME OF SALE",len(data[data["BUILDING CLASS AT TIME OF SALE"].isnull()]))   # this doesn't contain any nan values
print("Number of nan values present in SALE PRICE",len(data[data["SALE PRICE"].isnull()]))                                           # this doesn't contain any nan values
print("Number of nan values present in SALE DATE",len(data[data["SALE DATE"].isnull()]))                                             # this doesn't contain any nan values
# Out:
# Number of nan values present in NEIGHBORHOOD 0
# Number of nan values present in BUILDING CLASS CATEGORY 0
# Number of nan values present in BUILDING CLASS AT PRESENT 838
# Number of nan values present in BUILDING CLASS AT PRESENT 838
# Number of nan values present in TAX CLASS AT PRESENT 838
# Number of nan values present in BLOCK 0
# Number of nan values present in LOT 0
# Number of nan values present in ADDRESS 0
# Number of nan values present in APARTMENT NUMBER 470673
# Number of nan values present in ZIP CODE 47
# Number of nan values present in RESIDENTIAL UNITS 120893
# Number of nan values present in COMMERCIAL UNITS 190743
# Number of nan values present in TOTAL UNITS 109684
# Number of nan values present in LAND SQUARE FEET 201953
# Number of nan values present in GROSS SQUARE FEET 201952
# Number of nan values present in YEAR BUILT 36651
# Number of nan values present in TAX CLASS AT TIME OF SALE 0
# Number of nan values present in BUILDING CLASS AT TIME OF SALE 0
# ...

# %% [markdown]
# # Removing all the rows that contains nan value using Dropna

# %%
cleaned_data = data.dropna()

# %%
cleaned_data
# Out:
#         BOROUGH    NEIGHBORHOOD        BUILDING CLASS CATEGORY  \
# 6005          1  HARLEM-CENTRAL  11 SPECIAL CONDO BILLING LOTS
# 6639          1     HARLEM-EAST  11 SPECIAL CONDO BILLING LOTS
# 6640          1     HARLEM-EAST  11 SPECIAL CONDO BILLING LOTS
# 6852          1    HARLEM-UPPER  11 SPECIAL CONDO BILLING LOTS
# 7306          1        KIPS BAY  11 SPECIAL CONDO BILLING LOTS
# ...         ...             ...                            ...
# 1995329       4  FLUSHING-NORTH  11 SPECIAL CONDO BILLING LOTS
# 1995330       4  FLUSHING-NORTH  11 SPECIAL CONDO BILLING LOTS
# 1995331       4  FLUSHING-NORTH  11 SPECIAL CONDO BILLING LOTS
# 1995332       4  FLUSHING-NORTH  11 SPECIAL CONDO BILLING LOTS
# 2001286       4         JAMAICA  11 SPECIAL CONDO BILLING LOTS
#
#         TAX CLASS AT PRESENT  BLOCK   LOT BUILDING CLASS AT PRESENT  \
# 6005                       2   1774  1004                        RR
# 6639                       2   1790  1001                        RR
# ...

# %%
# All null values are removed
print("Number of nan values present in NEIGHBORHOOD",len(cleaned_data[cleaned_data["NEIGHBORHOOD"].isnull()]))
print("Number of nan values present in BUILDING CLASS CATEGORY",len(cleaned_data[cleaned_data["BUILDING CLASS CATEGORY"].isnull()]))
print("Number of nan values present in BUILDING CLASS AT PRESENT",len(cleaned_data[cleaned_data["BUILDING CLASS AT PRESENT"].isnull()]))
print("Number of nan values present in BUILDING CLASS AT PRESENT",len(cleaned_data[cleaned_data["BUILDING CLASS AT PRESENT"].isnull()]))
print("Number of nan values present in TAX CLASS AT PRESENT",len(cleaned_data[cleaned_data["TAX CLASS AT PRESENT"].isnull()]))
print("Number of nan values present in BLOCK",len(cleaned_data[cleaned_data["BLOCK"].isnull()]))
print("Number of nan values present in LOT",len(cleaned_data[cleaned_data["LOT"].isnull()]))
print("Number of nan values present in ADDRESS",len(cleaned_data[cleaned_data["ADDRESS"].isnull()]))
print("Number of nan values present in APARTMENT NUMBER",len(cleaned_data[cleaned_data["APARTMENT NUMBER"].isnull()]))
print("Number of nan values present in ZIP CODE",len(cleaned_data[cleaned_data[" ZIP CODE"].isnull()]))
print("Number of nan values present in RESIDENTIAL UNITS",len(cleaned_data[cleaned_data["RESIDENTIAL UNITS"].isnull()]))
print("Number of nan values present in COMMERCIAL UNITS",len(cleaned_data[cleaned_data["COMMERCIAL UNITS"].isnull()]))
print("Number of nan values present in TOTAL UNITS",len(cleaned_data[cleaned_data["TOTAL UNITS"].isnull()]))
print("Number of nan values present in LAND SQUARE FEET",len(cleaned_data[cleaned_data["LAND SQUARE FEET"].isnull()]))
print("Number of nan values present in GROSS SQUARE FEET",len(cleaned_data[cleaned_data["GROSS SQUARE FEET"].isnull()]))
print("Number of nan values present in YEAR BUILT",len(cleaned_data[cleaned_data["YEAR BUILT"].isnull()]))
print("Number of nan values present in TAX CLASS AT TIME OF SALE",len(cleaned_data[cleaned_data["TAX CLASS AT TIME OF SALE"].isnull()]))
print("Number of nan values present in BUILDING CLASS AT TIME OF SALE",len(cleaned_data[cleaned_data["BUILDING CLASS AT TIME OF SALE"].isnull()]))
print("Number of nan values present in SALE PRICE",len(cleaned_data[cleaned_data["SALE PRICE"].isnull()]))
print("Number of nan values present in SALE DATE",len(cleaned_data[cleaned_data["SALE DATE"].isnull()]))
# Out:
# Number of nan values present in NEIGHBORHOOD 0
# Number of nan values present in BUILDING CLASS CATEGORY 0
# Number of nan values present in BUILDING CLASS AT PRESENT 0
# Number of nan values present in BUILDING CLASS AT PRESENT 0
# Number of nan values present in TAX CLASS AT PRESENT 0
# Number of nan values present in BLOCK 0
# Number of nan values present in LOT 0
# Number of nan values present in ADDRESS 0
# Number of nan values present in APARTMENT NUMBER 0
# Number of nan values present in ZIP CODE 0
# Number of nan values present in RESIDENTIAL UNITS 0
# Number of nan values present in COMMERCIAL UNITS 0
# Number of nan values present in TOTAL UNITS 0
# Number of nan values present in LAND SQUARE FEET 0
# Number of nan values present in GROSS SQUARE FEET 0
# Number of nan values present in YEAR BUILT 0
# Number of nan values present in TAX CLASS AT TIME OF SALE 0
# Number of nan values present in BUILDING CLASS AT TIME OF SALE 0
# Number of nan values present in SALE PRICE 0
# ...

# %% [markdown]
# # Data is Cleaned
